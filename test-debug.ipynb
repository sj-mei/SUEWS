# %%
import pickle
import pandas as pd

# %%
dict_debug = pickle.load(open('dict_debug.pkl', 'rb'))
# df_debug = pd.read_pickle('df_debug.pkl')

# %%
dir(dict_debug[1].state_12_tsurf.heatstate)
# Out:
# ['__class__',
#  '__copy__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_alloc',
#  '_arrays',
#  '_dt_array_initialisers',
#  '_handle',
#  '_objs',
#  'allocate',
#  'copy',
#  'deallocate',
#  'from_handle',
#  'kclear',
#  'kup',
#  'ldown',
#  'lup',
#  'qe',
#  'qe0_surf',
#  'qe_lumps',
#  'qe_roof',
#  'qe_surf',
#  'qe_wall',
#  'qf',
#  'qf_sahp',
#  'qh',
#  'qh_init',
#  'qh_lumps',
#  'qh_residual',
#  'qh_resist',
#  'qh_resist_roof',
#  'qh_resist_surf',
#  'qh_resist_wall',
#  'qh_roof',
#  'qh_surf',
#  'qh_wall',
#  'qn',
#  'qn_roof',
#  'qn_snowfree',
#  'qn_surf',
# ...

# %%
dict_debug[1].state_12_tsurf.heatstate.tsfc_c
# Out:
# 0.0

# %%
dict_debug[1]["state_12_tsurf"]["heatstate"]["tsfc_surf"]
# Out:
# array([12.48363289, 12.54365661, 12.43839895, 12.43771037, 12.51253971,
#        12.49808241, 10.78921415])

# %%
from supy._post import pack_df_debug

pack_df_debug(dict_debug)
# .loc[1].loc["state_12_tsurf"].filter(like="tsfc_surf").values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 from supy._post import pack_df_debug
# ----> 3 pack_df_debug(dict_debug)
#       4 # .loc[1].loc["state_12_tsurf"].filter(like="tsfc_surf").values
#
# File ~/Dropbox (Personal)/6.Repos/SUEWS/src/supy/_post.py:351, in pack_df_debug(dict_debug)
#     340 """
#     341 Packs the debug dictionary into a DataFrame.
#     342
#    (...)
#     348
#     349 """
#     350 df_debug_raw = pack_df_debug_raw(dict_debug)
# --> 351 df_debug_raw.index = df_debug_raw.index.rename(
#     352     [
#     353         "datetime",
#     354         "grid",
#     355         "step",
#     356         "group",
#     357         "var",
#     358     ]
#     359 )
#     360 df_debug = (
#     361     df_debug_raw.unstack(level=["group", "var"])
#     362     .sort_index(level=0, axis=1)
# ...

# %%
df_debug.loc[1].loc["state_12_tsurf"].filter(like="tsfc_surf").values
# Out:
# array([array([2.13182125e-314, 2.13209935e-314, 2.13046950e-314, 2.13184187e-314,
#               2.13120947e-314, 2.13058495e-314, 2.13436859e-314])                ],
#       dtype=object)

# %%
import supy as sp
df_state_init, df_forcing = sp.load_SampleData()
# Out:
# ninja: error: '/private/var/folders/6r/lhkvk3m14ls587p81nfcy0k40000gp/T/pip-build-env-pw0vytis/overlay/bin/f90wrap', needed by 'src/supy_driver/f90wrap_suews_ctrl_type.f90', missing and no known rule to make it
# 2024-08-05 23:16:49,214 - SuPy - INFO - All cache cleared.

# %%
df_state = df_state_init.copy()
df_output, df_state_final, df_debug = sp.run_supy(
    df_forcing.iloc[: 288 * 2],
    df_state,
    debug_mode=True,
    chunk_day=1,
)
# Out:
# 2024-08-05 23:16:53,562 - SuPy - INFO - ====================
# 2024-08-05 23:16:53,562 - SuPy - INFO - Simulation period:
# 2024-08-05 23:16:53,563 - SuPy - INFO -   Start: 2012-01-01 00:05:00
# 2024-08-05 23:16:53,563 - SuPy - INFO -   End: 2012-01-03 00:00:00
# 2024-08-05 23:16:53,564 - SuPy - INFO -
# 2024-08-05 23:16:53,564 - SuPy - INFO - No. of grids: 1
# 2024-08-05 23:16:53,564 - SuPy - INFO - SuPy is running in serial mode
# 2024-08-05 23:16:53,611 - SuPy - INFO - Forcing is split into 2 chunks for less memory consumption.
# 2024-08-05 23:16:53,904 - SuPy - INFO - Execution time: 0.3 s
# 2024-08-05 23:16:53,912 - SuPy - INFO - ====================

# %%
df_debug
# Out:
# group                               anthroemisstate                      \
# var                                              fc fc_anthro fc_biogen
# datetime   grid step
# 2012-01-02 1    state_01_dailystate             0.0       0.0       0.0
#                 state_02_soilmoist              0.0       0.0       0.0
#                 state_03_wateruse               0.0       0.0       0.0
#                 state_04_anthroemis             0.0       0.0       0.0
#                 state_05_qn                     0.0       0.0       0.0
#                 state_06_qs                     0.0       0.0       0.0
#                 state_07_qhqe_lumps             0.0       0.0       0.0
#                 state_08_water                  0.0       0.0       0.0
#                 state_09_resist                 0.0       0.0       0.0
#                 state_10_qe                     0.0       0.0       0.0
#                 state_11_qh                     0.0       0.0       0.0
# ...
