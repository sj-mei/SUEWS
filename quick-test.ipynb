# %%
import supy as sp

df_state_init, df_forcing_tstep = sp.load_SampleData()
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# File ~/.local/share/mamba/envs/suews-dev/lib/python3.12/site-packages/_supy_editable_loader.py:345, in MesonpyMetaFinder._rebuild(self)
#     344     else:
# --> 345         subprocess.run(self._build_cmd, cwd=self._build_path, env=env, stdout=subprocess.DEVNULL, check=True)
#     346 except subprocess.CalledProcessError as exc:
#
# File ~/.local/share/mamba/envs/suews-dev/lib/python3.12/subprocess.py:571, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     570     if check and retcode:
# --> 571         raise CalledProcessError(retcode, process.args,
#     572                                  output=stdout, stderr=stderr)
#     573 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['/Users/tingsun/.local/share/mamba/envs/suews-dev/bin/ninja']' returned non-zero exit status 1.
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import supy as sp
#
# File ~/.local/share/mamba/envs/suews-dev/lib/python3.12/site-packages/_supy_editable_loader.py:311, in MesonpyMetaFinder.find_spec(self, fullname, path, target)
#     309 if self._build_path in os.environ.get(MARKER, '').split(os.pathsep):
#     310     return None
# --> 311 tree = self._rebuild()
#     312 return find_spec(fullname, tree)
#
# File ~/.local/share/mamba/envs/suews-dev/lib/python3.12/site-packages/_supy_editable_loader.py:347, in MesonpyMetaFinder._rebuild(self)
#     345         subprocess.run(self._build_cmd, cwd=self._build_path, env=env, stdout=subprocess.DEVNULL, check=True)
#     346 except subprocess.CalledProcessError as exc:
# --> 347     raise ImportError(f're-building the {self._name} meson-python editable wheel package failed') from exc
#     349 install_plan_path = os.path.join(self._build_path, 'meson-info', 'intro-install_plan.json')
#     350 with open(install_plan_path, 'r', encoding='utf8') as f:
#
# ImportError: re-building the supy meson-python editable wheel package failed

# %%
df_forcing_part = df_forcing_tstep.iloc[: 288 * 10]
df_output, df_state = sp.run_supy(
            df_forcing_part, df_state_init, check_input=True
        )
