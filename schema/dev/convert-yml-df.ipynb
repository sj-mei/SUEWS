# %%
import supy as sp
import pydantic as pdt
# %load_ext autoreload
# %autoreload 2

# %%
df_state,df_forcing=sp.load_SampleData()
# Out:
# 2024-11-14 23:46:47,132 - SuPy - INFO - All cache cleared.

# %%
# export columns to a file for mapping use
with open('df_state_columns.txt', 'w') as f:
    f.write('\n'.join([f'{col[0]},{col[1]}' for col in df_state.columns]))
df_state.filter(like='snow').columns
# Out:
# 22354
# MultiIndex([('narp_emis_snow',       '0'),
#             (    'snowalbmax',       '0'),
#             (    'snowalbmin',       '0'),
#             ( 'snowpacklimit',    '(0,)'),
#             ( 'snowpacklimit',    '(1,)'),
#             ( 'snowpacklimit',    '(2,)'),
#             ( 'snowpacklimit',    '(3,)'),
#             ( 'snowpacklimit',    '(4,)'),
#             ( 'snowpacklimit',    '(5,)'),
#             ( 'snowpacklimit',    '(6,)'),
#             (   'snowdensmax',       '0'),
#             (   'snowdensmin',       '0'),
#             (   'snowlimbldg',       '0'),
#             (  'snowlimpaved',       '0'),
#             ( 'snowprof_24hr',  '(0, 0)'),
#             ( 'snowprof_24hr',  '(0, 1)'),
#             ( 'snowprof_24hr',  '(1, 0)'),
#             ( 'snowprof_24hr',  '(1, 1)'),
#             ( 'snowprof_24hr',  '(2, 0)'),
#             ( 'snowprof_24hr',  '(2, 1)'),
#             ( 'snowprof_24hr',  '(3, 0)'),
#             ( 'snowprof_24hr',  '(3, 1)'),
#             ( 'snowprof_24hr',  '(4, 0)'),
#             ( 'snowprof_24hr',  '(4, 1)'),
#             ( 'snowprof_24hr',  '(5, 0)'),
#             ( 'snowprof_24hr',  '(5, 1)'),
#             ( 'snowprof_24hr',  '(6, 0)'),
#             ( 'snowprof_24hr',  '(6, 1)'),
#             ( 'snowprof_24hr',  '(7, 0)'),
#             ( 'snowprof_24hr',  '(7, 1)'),
#             ( 'snowprof_24hr',  '(8, 0)'),
#             ( 'snowprof_24hr',  '(8, 1)'),
#             ( 'snowprof_24hr',  '(9, 0)'),
#             ( 'snowprof_24hr',  '(9, 1)'),
#             ( 'snowprof_24hr', '(10, 0)'),
#             ( 'snowprof_24hr', '(10, 1)'),
#             ( 'snowprof_24hr', '(11, 0)'),
#             ( 'snowprof_24hr', '(11, 1)'),
#             ( 'snowprof_24hr', '(12, 0)'),
#             ( 'snowprof_24hr', '(12, 1)'),
#             ( 'snowprof_24hr', '(13, 0)'),
#             ( 'snowprof_24hr', '(13, 1)'),
#             ( 'snowprof_24hr', '(14, 0)'),
#             ( 'snowprof_24hr', '(14, 1)'),
#             ( 'snowprof_24hr', '(15, 0)'),
#             ( 'snowprof_24hr', '(15, 1)'),
#             ( 'snowprof_24hr', '(16, 0)'),
#             ( 'snowprof_24hr', '(16, 1)'),
#             ( 'snowprof_24hr', '(17, 0)'),
#             ( 'snowprof_24hr', '(17, 1)'),
#             ( 'snowprof_24hr', '(18, 0)'),
#             ( 'snowprof_24hr', '(18, 1)'),
#             ( 'snowprof_24hr', '(19, 0)'),
#             ( 'snowprof_24hr', '(19, 1)'),
#             ( 'snowprof_24hr', '(20, 0)'),
#             ( 'snowprof_24hr', '(20, 1)'),
#             ( 'snowprof_24hr', '(21, 0)'),
#             ( 'snowprof_24hr', '(21, 1)'),
#             ( 'snowprof_24hr', '(22, 0)'),
#             ( 'snowprof_24hr', '(22, 1)'),
#             ( 'snowprof_24hr', '(23, 0)'),
#             ( 'snowprof_24hr', '(23, 1)'),
#             (       'snowuse',       '0'),
#             (      'snowdens',    '(0,)'),
#             (      'snowdens',    '(1,)'),
#             (      'snowdens',    '(2,)'),
#             (      'snowdens',    '(3,)'),
#             (      'snowdens',    '(4,)'),
#             (      'snowdens',    '(5,)'),
#             (      'snowdens',    '(6,)'),
#             (      'snowfrac',    '(0,)'),
#             (      'snowfrac',    '(1,)'),
#             (      'snowfrac',    '(2,)'),
#             (      'snowfrac',    '(3,)'),
#             (      'snowfrac',    '(4,)'),
#             (      'snowfrac',    '(5,)'),
#             (      'snowfrac',    '(6,)'),
#             (      'snowpack',    '(0,)'),
#             (      'snowpack',    '(1,)'),
#             (      'snowpack',    '(2,)'),
#             (      'snowpack',    '(3,)'),
#             (      'snowpack',    '(4,)'),
#             (      'snowpack',    '(5,)'),
#             (      'snowpack',    '(6,)'),
#             (     'snowwater',    '(0,)'),
#             (     'snowwater',    '(1,)'),
#             (     'snowwater',    '(2,)'),
#             (     'snowwater',    '(3,)'),
#             (     'snowwater',    '(4,)'),
#             (     'snowwater',    '(5,)'),
#             (     'snowwater',    '(6,)'),
#             (   'snowfallcum',       '0'),
#             (       'snowalb',       '0')],
#            names=['var', 'ind_dim'])

# %%
df_state.columns.levels[0]

# %%
import yaml
import pandas as pd
from def_config_suews import SUEWSConfig


# Load YAML config
with open('./config-suews.yml', 'r') as file:
    yaml_config = yaml.safe_load(file)

# %%
# Create SUEWSConfig object
suews_config = SUEWSConfig(**yaml_config[0])
suews_config.site[0].properties
# Out:
# SiteProperties(lat=51.5074, lng=0.1278, alt=0.0, timezone=0, surfacearea=1.0, z=40.0, z0m_in=0.1, zdm_in=2.0, pipecapacity=100.0, runofftowater=0.5, narp_trans_site=1.0, lumps=LUMPSParams(raincover=0.5, rainmaxres=0.5, drainrt=0.5, veg_type=1), spartacus=SPARTACUSParams(air_ext_lw=1.0, air_ext_sw=1.0, air_ssa_lw=1.0, air_ssa_sw=1.0, ground_albedo_dir_mult_fact=1.0, n_stream_lw_urban=1, n_stream_sw_urban=1, n_vegetation_region_urban=1, sw_dn_direct_frac=1.0, use_sw_direct_albedo=0.1, veg_contact_fraction_const=1.0, veg_fsd_const=1.0, veg_ssa_lw=1.0, veg_ssa_sw=1.0), irrigation=IrrigationParams(h_maintain=10.0, faut=0.5, ie_start=100.0, ie_end=200.0, internalwateruse_h=10.0, daywatper=WeeklyProfile(monday=10.0, tuesday=10.0, wednesday=10.0, thursday=10.0, friday=10.0, saturday=10.0, sunday=10.0), daywat=WeeklyProfile(monday=10.0, tuesday=10.0, wednesday=10.0, thursday=10.0, friday=10.0, saturday=10.0, sunday=10.0), wuprofa_24hr=HourlyProfile(working_day={'1': 0.1, '2': 0.1, '3': 0.1, '4': 0.1, '5': 0.1, '6': 0.1, '7': 0.1, '8': 0.1, '9': 0.1, '10': 0.1, '11': 0.1, '12': 0.1, '13': 0.1, '14': 0.1, '15': 0.1, '16': 0.1, '17': 0.1, '18': 0.1, '19': 0.1, '20': 0.1, '21': 0.1, '22': 0.1, '23': 0.1, '24': 0.1}, holiday={'1': 0.1, '2': 0.1, '3': 0.1, '4': 0.1, '5': 0.1, '6': 0.1, '7': 0.1, '8': 0.1, '9': 0.1, '10': 0.1, '11': 0.1, '12': 0.1, '13': 0.1, '14': 0.1, '15': 0.1, '16': 0.1, '17': 0.1, '18': 0.1, '19': 0.1, '20': 0.1, '21': 0.1, '22': 0.1, '23': 0.1, '24': 0.1}), wuprofm_24hr=HourlyProfile(working_day={'1': 0.1, '2': 0.1, '3': 0.1, '4': 0.1, '5': 0.1, '6': 0.1, '7': 0.1, '8': 0.1, '9': 0.1, '10': 0.1, '11': 0.1, '12': 0.1, '13': 0.1, '14': 0.1, '15': 0.1, '16': 0.1, '17': 0.1, '18': 0.1, '19': 0.1, '20': 0.1, '21': 0.1, '22': 0.1, '23': 0.1, '24': 0.1}, holiday={'1': 0.1, '2': 0.1, '3': 0.1, '4': 0.1, '5': 0.1, '6': 0.1, '7': 0.1, '8': 0.1, '9': 0.1, '10': 0.1, '11': 0.1, '12': 0.1, '13': 0.1, '14': 0.1, '15': 0.1, '16': 0.1, '17': 0.1, '18': 0.1, '19': 0.1, '20': 0.1, '21': 0.1, '22': 0.1, '23': 0.1, '24': 0.1})), anthropogenic_emissions=AnthropogenicEmissions(startdls=150.0, enddls=250.0, heat=AnthropogenicHeat(qf0_beu=DayProfile(working_day=10.0, holiday=10.0), qf_a=DayProfile(working_day=10.0, holiday=10.0), qf_b=DayProfile(working_day=10.0, holiday=10.0), qf_c=DayProfile(working_day=10.0, holiday=10.0), baset_cooling=DayProfile(working_day=10.0, holiday=10.0), baset_heating=DayProfile(working_day=10.0, holiday=10.0), ah_min=0.1, ah_slope_cooling=0.1, ah_slope_heating=0.1, ahprof_24hr=HourlyProfile(working_day={'1': 0.1, '2': 0.1, '3': 0.1, '4': 0.1, '5': 0.1, '6': 0.1, '7': 0.1, '8': 0.1, '9': 0.1, '10': 0.1, '11': 0.1, '12': 0.1, '13': 0.1, '14': 0.1, '15': 0.1, '16': 0.1, '17': 0.1, '18': 0.1, '19': 0.1, '20': 0.1, '21': 0.1, '22': 0.1, '23': 0.1, '24': 0.1}, holiday={'1': 0.1, '2': 0.1, '3': 0.1, '4': 0.1, '5': 0.1, '6': 0.1, '7': 0.1, '8': 0.1, '9': 0.1, '10': 0.1, '11': 0.1, '12': 0.1, '13': 0.1, '14': 0.1, '15': 0.1, '16': 0.1, '17': 0.1, '18': 0.1, '19': 0.1, '20': 0.1, '21': 0.1, '22': 0.1, '23': 0.1, '24': 0.1})), co2=CO2Params(co2pointsource=0.1, ef_umolco2perj=0.1, enef_v_jkm=0.1, fcef_v_kgkm=0.1, frfossilfuel_heat=0.1, frfossilfuel_nonheat=0.1, maxfcmetab=0.1, maxqfmetab=0.1, min_res_bioco2=0.1, minfcmetab=0.1, minqfmetab=0.1, trafficrate=0.1, trafficunits=0.1, traffprof_24hr=HourlyProfile(working_day={'1': 0.1, '2': 0.1, '3': 0.1, '4': 0.1, '5': 0.1, '6': 0.1, '7': 0.1, '8': 0.1, '9': 0.1, '10': 0.1, '11': 0.1, '12': 0.1, '13': 0.1, '14': 0.1, '15': 0.1, '16': 0.1, '17': 0.1, '18': 0.1, '19': 0.1, '20': 0.1, '21': 0.1, '22': 0.1, '23': 0.1, '24': 0.1}, holiday={'1': 0.1, '2': 0.1, '3': 0.1, '4': 0.1, '5': 0.1, '6': 0.1, '7': 0.1, '8': 0.1, '9': 0.1, '10': 0.1, '11': 0.1, '12': 0.1, '13': 0.1, '14': 0.1, '15': 0.1, '16': 0.1, '17': 0.1, '18': 0.1, '19': 0.1, '20': 0.1, '21': 0.1, '22': 0.1, '23': 0.1, '24': 0.1}))), snow=SnowParams(crwmax=1.0, crwmin=0.3, narp_emis_snow=0.8, preciplimit=10.0, preciplimitalb=0 ...

# %%
def create_multi_index_columns(columns_file: str) -> pd.MultiIndex:
    """Create MultiIndex from df_state_columns.txt"""
    with open(columns_file, "r") as f:
            lines = f.readlines()

    tuples = []
    for line in lines:
        col_name, indices = line.strip().split(",", 1)
        str_indices = f"{indices}" if indices != "0" else "0"
        tuples.append((col_name, str_indices))
        # if indices == "0":
        #     tuples.append((col_name, 0))
        # else:
        #     # Convert string tuple to actual tuple
        #     indices = eval(indices)
        #     if isinstance(indices, int):
        #         indices = (indices,)
        #     tuples.append((col_name, *indices))

    return pd.MultiIndex.from_tuples(tuples)

columns = create_multi_index_columns('df_state_columns.txt')
df_state_test = pd.DataFrame(index=[0], columns=columns)
df_state_test.filter(like='snow').columns
# Out:
# MultiIndex([('narp_emis_snow',       '0'),
#             (    'snowalbmax',       '0'),
#             (    'snowalbmin',       '0'),
#             ( 'snowpacklimit',    '(0,)'),
#             ( 'snowpacklimit',    '(1,)'),
#             ( 'snowpacklimit',    '(2,)'),
#             ( 'snowpacklimit',    '(3,)'),
#             ( 'snowpacklimit',    '(4,)'),
#             ( 'snowpacklimit',    '(5,)'),
#             ( 'snowpacklimit',    '(6,)'),
#             (   'snowdensmax',       '0'),
#             (   'snowdensmin',       '0'),
#             (   'snowlimbldg',       '0'),
#             (  'snowlimpaved',       '0'),
#             ( 'snowprof_24hr',  '(0, 0)'),
#             ( 'snowprof_24hr',  '(0, 1)'),
#             ( 'snowprof_24hr',  '(1, 0)'),
#             ( 'snowprof_24hr',  '(1, 1)'),
#             ( 'snowprof_24hr',  '(2, 0)'),
#             ( 'snowprof_24hr',  '(2, 1)'),
#             ( 'snowprof_24hr',  '(3, 0)'),
#             ( 'snowprof_24hr',  '(3, 1)'),
#             ( 'snowprof_24hr',  '(4, 0)'),
#             ( 'snowprof_24hr',  '(4, 1)'),
#             ( 'snowprof_24hr',  '(5, 0)'),
#             ( 'snowprof_24hr',  '(5, 1)'),
#             ( 'snowprof_24hr',  '(6, 0)'),
#             ( 'snowprof_24hr',  '(6, 1)'),
#             ( 'snowprof_24hr',  '(7, 0)'),
#             ( 'snowprof_24hr',  '(7, 1)'),
#             ( 'snowprof_24hr',  '(8, 0)'),
#             ( 'snowprof_24hr',  '(8, 1)'),
#             ( 'snowprof_24hr',  '(9, 0)'),
#             ( 'snowprof_24hr',  '(9, 1)'),
#             ( 'snowprof_24hr', '(10, 0)'),
#             ( 'snowprof_24hr', '(10, 1)'),
#             ( 'snowprof_24hr', '(11, 0)'),
#             ( 'snowprof_24hr', '(11, 1)'),
#             ( 'snowprof_24hr', '(12, 0)'),
#             ( 'snowprof_24hr', '(12, 1)'),
#             ( 'snowprof_24hr', '(13, 0)'),
#             ( 'snowprof_24hr', '(13, 1)'),
#             ( 'snowprof_24hr', '(14, 0)'),
#             ( 'snowprof_24hr', '(14, 1)'),
#             ( 'snowprof_24hr', '(15, 0)'),
#             ( 'snowprof_24hr', '(15, 1)'),
#             ( 'snowprof_24hr', '(16, 0)'),
#             ( 'snowprof_24hr', '(16, 1)'),
#             ( 'snowprof_24hr', '(17, 0)'),
#             ( 'snowprof_24hr', '(17, 1)'),
#             ( 'snowprof_24hr', '(18, 0)'),
#             ( 'snowprof_24hr', '(18, 1)'),
#             ( 'snowprof_24hr', '(19, 0)'),
#             ( 'snowprof_24hr', '(19, 1)'),
#             ( 'snowprof_24hr', '(20, 0)'),
#             ( 'snowprof_24hr', '(20, 1)'),
#             ( 'snowprof_24hr', '(21, 0)'),
#             ( 'snowprof_24hr', '(21, 1)'),
#             ( 'snowprof_24hr', '(22, 0)'),
#             ( 'snowprof_24hr', '(22, 1)'),
#             ( 'snowprof_24hr', '(23, 0)'),
#             ( 'snowprof_24hr', '(23, 1)'),
#             (       'snowuse',       '0'),
#             (      'snowdens',    '(0,)'),
#             (      'snowdens',    '(1,)'),
#             (      'snowdens',    '(2,)'),
#             (      'snowdens',    '(3,)'),
#             (      'snowdens',    '(4,)'),
#             (      'snowdens',    '(5,)'),
#             (      'snowdens',    '(6,)'),
#             (      'snowfrac',    '(0,)'),
#             (      'snowfrac',    '(1,)'),
#             (      'snowfrac',    '(2,)'),
#             (      'snowfrac',    '(3,)'),
#             (      'snowfrac',    '(4,)'),
#             (      'snowfrac',    '(5,)'),
#             (      'snowfrac',    '(6,)'),
#             (      'snowpack',    '(0,)'),
#             (      'snowpack',    '(1,)'),
#             (      'snowpack',    '(2,)'),
#             (      'snowpack',    '(3,)'),
#             (      'snowpack',    '(4,)'),
#             (      'snowpack',    '(5,)'),
#             (      'snowpack',    '(6,)'),
#             (     'snowwater',    '(0,)'),
#             (     'snowwater',    '(1,)'),
#             (     'snowwater',    '(2,)'),
#             (     'snowwater',    '(3,)'),
#             (     'snowwater',    '(4,)'),
#             (     'snowwater',    '(5,)'),
#             (     'snowwater',    '(6,)'),
#             (   'snowfallcum',       '0'),
#             (       'snowalb',       '0')],
#            )

# %%
# # Convert to DataFrame
df_state_test = suews_config.to_df_state()
df_state_test

# # Convert back to SUEWSConfig
# suews_config_from_df = SUEWSConfig.from_df_state(df_state)

# # Convert back to DataFrame for comparison
# df_state_2 = suews_config_from_df.to_df_state()

# # Compare DataFrames
# pd.testing.assert_frame_equal(df_state, df_state_2)

# print("Conversion test passed successfully.")
# Out:
# MultiIndex([(          'ah_min',   '(0,)'),
#             (          'ah_min',   '(1,)'),
#             ('ah_slope_cooling',   '(0,)'),
#             ('ah_slope_cooling',   '(1,)'),
#             ('ah_slope_heating',   '(0,)'),
#             ('ah_slope_heating',   '(1,)'),
#             (     'ahprof_24hr', '(0, 0)'),
#             (     'ahprof_24hr', '(0, 1)'),
#             (     'ahprof_24hr', '(1, 0)'),
#             (     'ahprof_24hr', '(1, 1)'),
#             ...
#             (       'tsfc_wall',   '(0,)'),
#             (       'tsfc_wall',   '(1,)'),
#             (       'tsfc_wall',   '(2,)'),
#             (       'tsfc_surf',   '(0,)'),
#             (       'tsfc_surf',   '(1,)'),
#             (       'tsfc_surf',   '(2,)'),
#             (       'tsfc_surf',   '(3,)'),
#             (       'tsfc_surf',   '(4,)'),
#             (       'tsfc_surf',   '(5,)'),
#             (       'tsfc_surf',   '(6,)')],
#            length=1288)
#   ah_min      ah_slope_cooling      ah_slope_heating      ahprof_24hr         \
#     (0,) (1,)             (0,) (1,)             (0,) (1,)      (0, 0) (0, 1)
# 0    NaN  NaN              NaN  NaN              NaN  NaN         0.1    0.1
#
#                  ... emis sfr_surf   alb emis sfr_surf  alb emis sfr_surf  \
#   (1, 0) (1, 1)  ...  (3)      (4)   (4)  (4)      (5)  (5)  (5)      (6)
# 0    0.1    0.1  ...  0.9      0.1  0.15  0.9      0.1  0.1  0.9      0.4
#
#    alb emis
#    (6)  (6)
# 0  0.1  0.9
#
# [1 rows x 1309 columns]

# %%
df_state
# Out:
# var     ah_min       ah_slope_cooling      ah_slope_heating      ahprof_24hr  \
# ind_dim   (0,)  (1,)             (0,) (1,)             (0,) (1,)      (0, 0)
# grid
# 1         15.0  15.0              2.7  2.7              2.7  2.7        0.57
#
# var                           ... tsfc_wall           tsfc_surf            \
# ind_dim (0, 1) (1, 0) (1, 1)  ...      (0,) (1,) (2,)      (0,) (1,) (2,)
# grid                          ...
# 1         0.65   0.45   0.49  ...         5    5    5         2    2    2
#
# var
# ind_dim (3,) (4,) (5,) (6,)
# grid
# 1          2    2    2    2
#
# [1 rows x 1288 columns]
